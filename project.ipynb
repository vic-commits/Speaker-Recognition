# %% [markdown]
# <a href="https://colab.research.google.com/github/vic-commits/Speaker-Recognition/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Speaker Recognition Using FFTs in a ResNet architecture

# %% [markdown]
# ## Import dependencies

# %%
from posixpath import join
import os
import shutil
import tensorflow as tf
import keras
from pathlib import Path
import numpy as np
import zipfile
import soundfile as sf
from IPython.display import Audio, display

# %% [markdown]
# ## Dataset generation

# %%
#This model comes with a homemade dataset of 30 samples
DATASET_ROOT = "/content/drive/MyDrive/Colab Notebooks/speaker_recognition/dataset/audio"
DATASET_ROOT = Path(DATASET_ROOT)
AUDIO_SUBFOLDER = "audio"
DATASET_AUDIO_PATH = (DATASET_ROOT.parent / AUDIO_SUBFOLDER)
VALID_SPLIT = 0.2
SHUFFLE_SEED = 43
SAMPLING_RATE = 44100
SCALE =0.5
BATCH_SIZE = 128
EPOCHS = 100
MIN_AUDIO_LENGTH = 0.5
# read files
for folder in os.listdir(DATASET_AUDIO_PATH):
    if os.path.isdir(os.path.join(DATASET_AUDIO_PATH, folder)):
        if folder in AUDIO_SUBFOLDER:
            continue
# dataset generation
def paths_and_labels_to_dataset(audio_paths, labels):
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(
        lambda x: path_to_audio(x), num_parallel_calls=tf.data.AUTOTUNE
    )
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))
def path_to_audio(path):
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio

def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)
        prop = tf.math.reduce_max(audio, axis=1)/ tf.math.reduce_max(noise, axis=1)
        prop= tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)
        audio = audio + noise * prop * scale
        return audio

#Break each audio file in a FFT
def audio_to_fft(audio, min_n_fft=256, max_n_fft=2048):
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)
    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])
class_names= os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))
num_classes = len(class_names)
audio_paths = []
labels = []
for label, name in enumerate(class_names):
  print("Processing speaker {}".format(name,))
  dir_path = Path(DATASET_AUDIO_PATH/name)
  if os.path.isdir(dir_path):
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)]
    audio_paths += speaker_sample_paths
    labels += [label]*len(speaker_sample_paths)
print("Audio files count: {}. Classes: {}".format(len(audio_paths), len(class_names)))
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]
print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]
#Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE)
valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)
noise=tf.random.normal(shape=[BATCH_SIZE,SAMPLING_RATE])
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)
valid_ds = valid_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Our class names: ['Michelle', 'Victoria', '.ipynb_checkpoints']
# Processing speaker Michelle
# Processing speaker Victoria
# Processing speaker .ipynb_checkpoints
# Audio files count: 30. Classes: 3
# Using 24 files for training.
# Using 6 files for validation.

# %% [markdown]
# ## Model definition

# %%
from keras import regularizers
def residual_block(x, filters, conv_num=2, activation='relu'):
  s = keras.layers.Conv1D(filters, 1, padding='same', kernel_regularizer=regularizers.l2(0.01))(x)
  x = keras.layers.Conv1D(filters, 2, padding="same", kernel_regularizer=regularizers.l2(0.01))(x)
  x = keras.layers.Add()([x, s])
  x = keras.layers.Activation(activation)(x)
  return keras.layers.MaxPool1D(pool_size=1, strides=1)(x)
def build_model(input_shape, num_classes, dropout_rate=0.3, l2_regularization=0.01):
  inputs = keras.layers.Input(shape=input_shape, name='input')
  x = residual_block(inputs, 8)
  x = residual_block(x,16)
  x = keras.layers.AveragePooling1D(pool_size=1, strides=1)(x)
  x = keras.layers.Flatten()(x)
  x = keras.layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(l2_regularization))(x)
  x = keras.layers.Dropout(dropout_rate)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  return keras.models.Model(inputs=inputs, outputs=outputs)

input_shape=(SAMPLING_RATE // 2, 1)
model = build_model(input_shape, num_classes)
model.summary()

optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_save_file = "model.keras"
earlystopping_cb = keras.callbacks.EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(model_save_file, monitor="val_accuracy", save_best_only=True)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=3)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 22050, 1)       │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 22050, 8)       │             24 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 22050, 8)       │             16 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 22050, 8)       │              0 │ conv1d_1[0][0],        │
# │                           │                        │                │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 22050, 8)       │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d             │ (None, 22050, 8)       │              0 │ activation[0][0]       │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 22050, 16)      │            272 │ max_pooling1d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 22050, 16)      │            144 │ max_pooling1d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 22050, 16)      │              0 │ conv1d_3[0][0],        │
# │                           │                        │                │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 22050, 16)      │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d_1           │ (None, 22050, 16)      │              0 │ activation_1[0][0]     │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling1d         │ (None, 22050, 16)      │              0 │ max_pooling1d_1[0][0]  │
# │ (AveragePooling1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 352800)         │              0 │ average_pooling1d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 8)              │      2,822,408 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 8)              │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 3)              │             27 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,822,891 (10.77 MB)
#  Trainable params: 2,822,891 (10.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Hyperparameter tuning

# %%
from scipy.stats import uniform, randint
import random
param_distribution = {
    'optimizer': ['Adam','SGD'],
    'learning_rate': uniform(loc=1e-5, scale=1e-3 - 1e-5),
    'batch_size': [32, 64, 128],
    'epochs': randint(low=50, high=151),
    'dropout_rate': uniform(loc=0.2, scale=0.4 - 0.2),
    'l2_regularization': uniform(loc=0.001, scale=0.01 - 0.001),
}

num_iterations = 20
best_accuracy = 0
best_hyperparameters = {}
for _ in range(num_iterations):
    hyperparameters = {
        'optimizer': random.choice(param_distribution['optimizer']),
        'learning_rate': param_distribution['learning_rate'].rvs(),
        'batch_size': random.choice(param_distribution['batch_size']),
        'epochs': param_distribution['epochs'].rvs(),
        'dropout_rate': param_distribution['dropout_rate'].rvs(),
        'l2_regularization': param_distribution['l2_regularization'].rvs(),
    }
    model = build_model(input_shape, num_classes, dropout_rate=hyperparameters['dropout_rate'], l2_regularization=hyperparameters['l2_regularization'])
    optimizer = getattr(keras.optimizers, hyperparameters['optimizer'])(learning_rate=hyperparameters['learning_rate'])
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(
        train_ds,
        epochs=hyperparameters['epochs'],
        validation_data=valid_ds,
        callbacks=[earlystopping_cb, mdlcheckpoint_cb],
    )

    _, accuracy = model.evaluate(valid_ds)

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_hyperparameters = hyperparameters

print("Best Hyperparameters:", best_hyperparameters)
print("Best Validation Accuracy:", best_accuracy)
# Out:
# Epoch 1/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4583 - loss: 1.4272 - val_accuracy: 0.6667 - val_loss: 1.6934
# Epoch 2/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.6250 - loss: 4.8211 - val_accuracy: 0.5000 - val_loss: 2.3266
# Epoch 3/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6667 - loss: 4.3078 - val_accuracy: 0.6667 - val_loss: 1.2573
# Epoch 4/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step - accuracy: 0.8750 - loss: 0.9212 - val_accuracy: 0.6667 - val_loss: 1.3924
# Epoch 5/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9167 - loss: 0.8434 - val_accuracy: 0.6667 - val_loss: 1.2052
# Epoch 6/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7917 - loss: 1.9724 - val_accuracy: 0.6667 - val_loss: 1.0555
# Epoch 7/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step - accuracy: 0.8750 - loss: 0.6230 - val_accuracy: 0.6667 - val_loss: 1.0485
# Epoch 8/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9167 - loss: 0.4745 - val_accuracy: 0.6667 - val_loss: 1.0909
# Epoch 9/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step - accuracy: 0.8750 - loss: 1.3689 - val_accuracy: 0.6667 - val_loss: 1.1392
# Epoch 10/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.4471 - val_accuracy: 0.6667 - val_loss: 1.1982
# Epoch 11/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7917 - loss: 0.8570 - val_accuracy: 0.6667 - val_loss: 1.2446
# Epoch 12/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.9167 - loss: 0.4457 - val_accuracy: 0.6667 - val_loss: 1.2957
# Epoch 13/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9167 - loss: 0.5137 - val_accuracy: 0.6667 - val_loss: 1.3491
# Epoch 14/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step - accuracy: 0.9167 - loss: 0.4059 - val_accuracy: 0.6667 - val_loss: 1.4101
# Epoch 15/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.4173 - val_accuracy: 0.6667 - val_loss: 1.4798
# Epoch 16/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.4933 - val_accuracy: 0.6667 - val_loss: 1.5576
# Epoch 17/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step - accuracy: 0.9167 - loss: 0.4647 - val_accuracy: 0.6667 - val_loss: 1.6439
# Epoch 18/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step - accuracy: 0.8750 - loss: 0.5732 - val_accuracy: 0.6667 - val_loss: 1.7292
# Epoch 19/135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9167 - loss: 0.4082 - val_accuracy: 0.6667 - val_loss: 1.7887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6667 - loss: 1.4101
# Epoch 1/110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1667 - loss: 10.6610 - val_accuracy: 0.6667 - val_loss: 64.3343
# Epoch 2/110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 143.9623 - val_accuracy: 0.3333 - val_loss: 93.5098
# Epoch 3/110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 98.5121 - val_accuracy: 0.6667 - val_loss: 2.2449
# Epoch 4/110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6667 - loss: 2.5787 - val_accuracy: 0.3333 - val_loss: 1.1223
# Epoch 5/110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 1.3116 - val_accuracy: 0.3333 - val_loss: 1.2213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6667 - loss: 64.3343
# Epoch 1/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.2500 - loss: 19.5822 - val_accuracy: 0.3333 - val_loss: 161.0704
# Epoch 2/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 147.1536 - val_accuracy: 0.6667 - val_loss: 14.5070
# Epoch 3/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6250 - loss: 18.2071 - val_accuracy: 0.6667 - val_loss: 19.9750
# Epoch 4/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 827ms/step - accuracy: 0.4583 - loss: 51.8255 - val_accuracy: 0.6667 - val_loss: 19.4221
# Epoch 5/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4167 - loss: 56.1782 - val_accuracy: 0.6667 - val_loss: 16.7448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3333 - loss: 161.0704
# Epoch 1/122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.3333 - loss: 5.7665 - val_accuracy: 0.3333 - val_loss: 84.1923
# Epoch 2/122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 874ms/step - accuracy: 0.5417 - loss: 75.0824 - val_accuracy: 0.6667 - val_loss: 12.6618
# Epoch 3/122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 829ms/step - accuracy: 0.4583 - loss: 22.7031 - val_accuracy: 0.3333 - val_loss: 5.9408
# Epoch 4/122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5833 - loss: 2.6629 - val_accuracy: 0.6667 - val_loss: 3.3163
# Epoch 5/122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4583 - loss: 6.2815 - val_accuracy: 0.6667 - val_loss: 1.0140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3333 - loss: 84.1923
# Epoch 1/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5000 - loss: 5.7386 - val_accuracy: 0.6667 - val_loss: 1.5206
# Epoch 2/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4583 - loss: 3.2973 - val_accuracy: 0.5000 - val_loss: 3.2910
# Epoch 3/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step - accuracy: 0.5417 - loss: 14.7158 - val_accuracy: 0.6667 - val_loss: 24.2517
# Epoch 4/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 41.5472 - val_accuracy: 0.3333 - val_loss: 1.4633
# Epoch 5/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 1.4631 - val_accuracy: 0.3333 - val_loss: 1.4632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6667 - loss: 1.5206
# Epoch 1/114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0417 - loss: 16.2057 - val_accuracy: 0.6667 - val_loss: 71.5233
# Epoch 2/114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5833 - loss: 159.5858 - val_accuracy: 0.6667 - val_loss: 16.8367
# Epoch 3/114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 37.1179 - val_accuracy: 0.3333 - val_loss: 12.5027
# Epoch 4/114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5417 - loss: 8.8863 - val_accuracy: 0.3333 - val_loss: 14.6098
# Epoch 5/114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 11.7285 - val_accuracy: 0.3333 - val_loss: 15.7162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6667 - loss: 71.5233
# Epoch 1/127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1250 - loss: 8.5565 - val_accuracy: 0.5000 - val_loss: 1.3090
# Epoch 2/127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5417 - loss: 2.7525 - val_accuracy: 0.3333 - val_loss: 1.4763
# Epoch 3/127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5417 - loss: 1.4763 - val_accuracy: 0.3333 - val_loss: 1.4684
# Epoch 4/127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5417 - loss: 1.4684 - val_accuracy: 0.3333 - val_loss: 1.4619
# Epoch 5/127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 1.4618 - val_accuracy: 0.3333 - val_loss: 1.4566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5000 - loss: 1.3090
# Epoch 1/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.5000 - loss: 4.3561 - val_accuracy: 0.6667 - val_loss: 4.3791
# Epoch 2/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step - accuracy: 0.4583 - loss: 10.2076 - val_accuracy: 0.6667 - val_loss: 2.3298
# Epoch 3/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5833 - loss: 3.0911 - val_accuracy: 0.6667 - val_loss: 1.9538
# Epoch 4/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step - accuracy: 0.6250 - loss: 1.3299 - val_accuracy: 0.3333 - val_loss: 1.9757
# Epoch 5/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5417 - loss: 2.0429 - val_accuracy: 0.3333 - val_loss: 1.4433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6667 - loss: 4.3791
# Epoch 1/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.2917 - loss: 8.9013 - val_accuracy: 0.3333 - val_loss: 10.4565
# Epoch 2/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step - accuracy: 0.4583 - loss: 29.8461 - val_accuracy: 0.3333 - val_loss: 38.4053
# Epoch 3/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step - accuracy: 0.4583 - loss: 46.4215 - val_accuracy: 0.3333 - val_loss: 34.9079
# Epoch 4/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - accuracy: 0.5417 - loss: 34.0039 - val_accuracy: 0.6667 - val_loss: 17.2417
# Epoch 5/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 10.6649 - val_accuracy: 0.6667 - val_loss: 1.4433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3333 - loss: 10.4565
# Epoch 1/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.4583 - loss: 28.6764 - val_accuracy: 0.6667 - val_loss: 1.0996
# Epoch 2/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4583 - loss: 1.2159 - val_accuracy: 0.6667 - val_loss: 1.0376
# Epoch 3/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4583 - loss: 1.1126 - val_accuracy: 0.6667 - val_loss: 0.9890
# Epoch 4/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4583 - loss: 1.1660 - val_accuracy: 0.6667 - val_loss: 0.9869
# Epoch 5/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3750 - loss: 1.1557 - val_accuracy: 0.6667 - val_loss: 0.9961
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6667 - loss: 1.0996
# Epoch 1/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2917 - loss: 7.8964 - val_accuracy: 0.0000e+00 - val_loss: 128.7645
# Epoch 2/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step - accuracy: 0.0833 - loss: 168.3777 - val_accuracy: 0.6667 - val_loss: 16.1228
# Epoch 3/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 25.1495 - val_accuracy: 0.3333 - val_loss: 7.9311
# Epoch 4/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - accuracy: 0.5417 - loss: 8.6896 - val_accuracy: 0.6667 - val_loss: 9.4203
# Epoch 5/121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step - accuracy: 0.3750 - loss: 17.9998 - val_accuracy: 0.6667 - val_loss: 0.7702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0000e+00 - loss: 128.7645
# Epoch 1/138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.2500 - loss: 18.9301 - val_accuracy: 0.5000 - val_loss: 11.9007
# Epoch 2/138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2917 - loss: 48.4561 - val_accuracy: 0.3333 - val_loss: 35.7227
# Epoch 3/138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step - accuracy: 0.5417 - loss: 30.3685 - val_accuracy: 0.3333 - val_loss: 21.2138
# Epoch 4/138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 11.4982 - val_accuracy: 0.1667 - val_loss: 8.4790
# Epoch 5/138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 5.1905 - val_accuracy: 0.3333 - val_loss: 2.7226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5000 - loss: 11.9007
# Epoch 1/86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 10.5170 - val_accuracy: 0.6667 - val_loss: 42.6272
# Epoch 2/86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step - accuracy: 0.5833 - loss: 78.3311 - val_accuracy: 0.3333 - val_loss: 270.7889
# Epoch 3/86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5417 - loss: 268.0284 - val_accuracy: 0.3333 - val_loss: 2.1133
# Epoch 4/86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4583 - loss: 2.3922 - val_accuracy: 0.6667 - val_loss: 0.9462
# Epoch 5/86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4167 - loss: 3.3065 - val_accuracy: 0.6667 - val_loss: 0.9956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6667 - loss: 42.6272
# Epoch 1/53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2917 - loss: 3.3230 - val_accuracy: 0.3333 - val_loss: 23.7492
# Epoch 2/53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 812ms/step - accuracy: 0.5833 - loss: 8.3458 - val_accuracy: 0.3333 - val_loss: 8.6510
# Epoch 3/53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 6.1861 - val_accuracy: 0.1667 - val_loss: 1.3921
# Epoch 4/53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step - accuracy: 0.2917 - loss: 1.3555 - val_accuracy: 0.6667 - val_loss: 1.3935
# Epoch 5/53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step - accuracy: 0.5000 - loss: 1.3022 - val_accuracy: 0.6667 - val_loss: 1.4021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3333 - loss: 23.7492
# Epoch 1/144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0833 - loss: 18.7062 - val_accuracy: 0.6667 - val_loss: 48.6185
# Epoch 2/144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - accuracy: 0.5417 - loss: 87.5957 - val_accuracy: 0.5000 - val_loss: 21.3889
# Epoch 3/144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 72.5644 - val_accuracy: 0.5000 - val_loss: 35.3128
# Epoch 4/144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7917 - loss: 32.4086 - val_accuracy: 0.6667 - val_loss: 19.1715
# Epoch 5/144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step - accuracy: 0.7917 - loss: 5.9585 - val_accuracy: 0.5000 - val_loss: 2.1675
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6667 - loss: 48.6185
# Epoch 1/150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6250 - loss: 2.1327 - val_accuracy: 0.5000 - val_loss: 31.1284
# Epoch 2/150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step - accuracy: 0.4583 - loss: 32.6745 - val_accuracy: 0.6667 - val_loss: 2.9029
# Epoch 3/150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6250 - loss: 3.7174 - val_accuracy: 0.6667 - val_loss: 1.0908
# Epoch 4/150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 1.2686 - val_accuracy: 0.6667 - val_loss: 1.0907
# Epoch 5/150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7083 - loss: 1.2228 - val_accuracy: 0.6667 - val_loss: 1.0906
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5000 - loss: 31.1284
# Epoch 1/67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3750 - loss: 8.2516 - val_accuracy: 0.3333 - val_loss: 17.7191
# Epoch 2/67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3333 - loss: 18.8011 - val_accuracy: 0.6667 - val_loss: 3.5740
# Epoch 3/67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step - accuracy: 0.4583 - loss: 6.1774 - val_accuracy: 0.3333 - val_loss: 1.4875
# Epoch 4/67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step - accuracy: 0.5833 - loss: 1.4417 - val_accuracy: 0.3333 - val_loss: 1.4874
# Epoch 5/67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 1.7041 - val_accuracy: 0.3333 - val_loss: 1.4873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3333 - loss: 17.7191
# Epoch 1/145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2500 - loss: 7.8739 - val_accuracy: 0.3333 - val_loss: 11.4729
# Epoch 2/145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - accuracy: 0.6250 - loss: 11.8174 - val_accuracy: 0.6667 - val_loss: 4.5002
# Epoch 3/145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4583 - loss: 7.3056 - val_accuracy: 0.6667 - val_loss: 1.1427
# Epoch 4/145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7083 - loss: 2.2358 - val_accuracy: 0.6667 - val_loss: 1.2153
# Epoch 5/145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6250 - loss: 1.4936 - val_accuracy: 0.3333 - val_loss: 1.5090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3333 - loss: 11.4729
# Epoch 1/58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4167 - loss: 4.0251 - val_accuracy: 0.6667 - val_loss: 61.8306
# Epoch 2/58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step - accuracy: 0.4583 - loss: 160.5329 - val_accuracy: 0.3333 - val_loss: 1.4224
# Epoch 3/58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 1.3095 - val_accuracy: 0.3333 - val_loss: 1.1210
# Epoch 4/58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 1.2851 - val_accuracy: 0.6667 - val_loss: 1.0312
# Epoch 5/58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step - accuracy: 0.4583 - loss: 1.2236 - val_accuracy: 0.3333 - val_loss: 1.6430
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6667 - loss: 61.8306
# Epoch 1/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.2500 - loss: 16.1073 - val_accuracy: 0.6667 - val_loss: 32.4257
# Epoch 2/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5417 - loss: 454.2521 - val_accuracy: 0.3333 - val_loss: 24.6413
# Epoch 3/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 29.1878 - val_accuracy: 0.3333 - val_loss: 27.2044
# Epoch 4/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4167 - loss: 27.8588 - val_accuracy: 0.6667 - val_loss: 1.6272
# Epoch 5/126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step - accuracy: 0.4583 - loss: 1.6837 - val_accuracy: 0.6667 - val_loss: 1.6270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6667 - loss: 32.4257
# Best Hyperparameters: {'optimizer': 'Adam', 'learning_rate': 0.0009671533663578511, 'batch_size': 128, 'epochs': 135, 'dropout_rate': 0.379794614630806, 'l2_regularization': 0.0015097378952056593}
# Best Validation Accuracy: 0.6666666865348816

# %% [markdown]
# ## Model training

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step - accuracy: 0.5833 - loss: 657.6513 - val_accuracy: 0.3333 - val_loss: 2.7683
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4583 - loss: 5.4440 - val_accuracy: 0.6667 - val_loss: 1.6219
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 875ms/step - accuracy: 0.4583 - loss: 1.6221 - val_accuracy: 0.6667 - val_loss: 1.6218
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step - accuracy: 0.4583 - loss: 1.6219 - val_accuracy: 0.6667 - val_loss: 1.6216
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4583 - loss: 1.6217 - val_accuracy: 0.6667 - val_loss: 1.6214

# %% [markdown]
# ## Model evaluation

# %%
print(model.evaluate(valid_ds))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3333 - loss: 2.7683
# [2.768285036087036, 0.3333333432674408]

# %% [markdown]
# ## Model demonstration

# %%
SAMPLES_TO_DISPLAY = 10
test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

for audios, labels in test_ds.take(1):
  actual_batch_size = tf.shape(audios)[0]
  noise = tf.random.normal(shape=[actual_batch_size, SAMPLING_RATE, 1])
  break

test_ds = test_ds.map(
    lambda x, y: (add_noise(x, noise, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

for audios, labels in test_ds.take(1):
    ffts = audio_to_fft(audios)
    y_pred = model.predict(ffts)
    actual_batch_size = tf.shape(audios)[0]
    rnd = np.random.randint(0, actual_batch_size.numpy(), SAMPLES_TO_DISPLAY)
    SAMPLES_TO_DISPLAY = min(SAMPLES_TO_DISPLAY, actual_batch_size.numpy())
    audios = audios.numpy()[rnd, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]
    for index in range(SAMPLES_TO_DISPLAY):
      print(
        'Speaker:\33{} {}\33[0M\tPredicted:\33{} {}\33[0m'.format(
            "green" if labels[index] == y_pred[index] else "red",
            class_names[labels[index]],
            "green" if labels[index] == y_pred[index] else "red",
            class_names[y_pred[index]],
          )
      )
      display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Speaker:red Victoria	Predicted:red Michelle
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker:green Michelle	Predicted:green Michelle
# Speaker:red Victoria	Predicted:red Michelle
# Speaker:green Michelle	Predicted:green Michelle
# Speaker:red Victoria	Predicted:red Michelle
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker:green Michelle	Predicted:green Michelle
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
